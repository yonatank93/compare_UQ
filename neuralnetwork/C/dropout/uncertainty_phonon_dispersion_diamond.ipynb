# %% [markdown]
# In this notebook, I want to compute the uncertainty of the phonon dispersion curves from the bootstrap ensembles.

# %%
from pathlib import Path
import pickle
import json
import re
from datetime import datetime
from tqdm import tqdm
import sys
from multiprocessing import Pool

from ase.build import bulk
from ase.calculators.kim import KIM
from ase.phonons import Phonons
from ase.visualize import view

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("default")

# %%
# Read settings
WORK_DIR = Path().absolute()
ROOT_DIR = WORK_DIR.parent
SETTINGS_DIR = ROOT_DIR / "settings"

settings_path = SETTINGS_DIR / "settings0.json"
with open(settings_path, "r") as f:
    settings = json.load(f)

RES_DIR = WORK_DIR / "results" / re.match(r"^[^_\.]+", settings_path.name).group()
if not RES_DIR.exists():
    RES_DIR.mkdir(parents=True)
PLOT_DIR = RES_DIR / "plots"
if not PLOT_DIR.exists():
    PLOT_DIR.mkdir(parents=True)

# %%
# Diamond bulk
a0 = 3.56
atoms = bulk("C", "diamond", a0)
# view(atoms.repeat((1, 1, 1)))

# %%
potential = "DUNN_best_train"
# potential = "DUNN_WenTadmor_2019v3_C__MO_714772088128_000"


def phonon_wrapper(set_idx):
    sample_dir = RES_DIR / f"{set_idx:03d}"

    # Phonon calculator
    calc = KIM(potential)
    calc.set_parameters(active_member_id=[[0], [set_idx + 1]])
    ph = Phonons(
        atoms, calc, supercell=(7, 7, 7), delta=0.1, name=sample_dir / "phonon_diamond"
    )
    ph.run()

    # Read forces and assemble the dynamical matrix
    ph.read(acoustic=True)
    # ph.clean()

    path = atoms.cell.bandpath("GXKGL", npoints=100)
    bs = ph.get_band_structure(path)
    return bs.energies


with Pool(25) as p:
    energies = np.array(list(p.map(phonon_wrapper, range(100))))

energies = energies[:, 0]
# Out:
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.047e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.047e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.134e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.194e-08*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.434e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.134e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.194e-08*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.434e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.777e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.531e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.777e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.470e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 2.653e-02*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.531e-08*i)
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.470e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.605e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.246e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.520e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.624e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.075e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.605e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.246e-08*i)
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.520e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.075e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.624e-08*i)
#
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.092e-07*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.629e-08*i)
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.919e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.641e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.154e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.962e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.915e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.560e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.360e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.092e-07*i)
#
#
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.749e-08*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 1.150e-01*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.629e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 2.215e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.749e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.915e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.962e-08*i)
#
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.560e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.641e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.360e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.154e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 3.112e-01*i)
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.991e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.081e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 3.754e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.676e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.991e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.10,  0.00,  0.10) ; (omega_q = 4.043e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.081e-08*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 3.839e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.197e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.246e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.13,  0.00,  0.13) ; (omega_q = 2.823e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.467e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.676e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.197e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.16) ; (omega_q = 1.517e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.246e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.467e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.07,  0.07,  0.13) ; (omega_q = 2.793e-01*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.05,  0.05,  0.11) ; (omega_q = 2.978e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.04,  0.04,  0.08) ; (omega_q = 2.638e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 1.949e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.018e-07*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.711e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.271e-08*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 1.032e-01*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.271e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.711e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.919e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.110e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.414e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.018e-07*i)
#
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.587e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.843e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.072e-08*i)
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 9.192e-02*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.557e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 1.912e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 4.143e-02*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.843e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 1.741e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.072e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.587e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 1.605e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 6.945e-02*i)
#
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.06,  0.06,  0.06) ; (omega_q = 2.364e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 3.729e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 3.119e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 6.049e-02*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.256e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.691e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.08) ; (omega_q = 2.673e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 5.359e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.747e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 4.456e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 3.333e-02*i)
#
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.10,  0.10,  0.10) ; (omega_q = 2.486e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 6.718e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 5.531e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.300e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 2.340e-02*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 1.256e-08*i)
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.747e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.691e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.12) ; (omega_q = 1.143e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.10,  0.00,  0.10) ; (omega_q = 7.730e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.10,  0.00,  0.10) ; (omega_q = 6.266e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.414e-08*i)
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 8.327e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 3.934e-02*i)
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 6.584e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.300e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.13,  0.00,  0.13) ; (omega_q = 8.447e-01*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 5.782e-02*i)
# WARNING, 1 imaginary frequencies at q = ( 0.13,  0.00,  0.13) ; (omega_q = 6.394e-01*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.15,  0.00,  0.15) ; (omega_q = 8.019e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.515e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.15,  0.00,  0.15) ; (omega_q = 5.550e-01*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.312e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.17,  0.00,  0.17) ; (omega_q = 6.930e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.527e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.746e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.17,  0.00,  0.17) ; (omega_q = 3.608e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.19,  0.00,  0.19) ; (omega_q = 4.851e-01*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.515e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.312e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.11,  0.11,  0.21) ; (omega_q = 3.411e-02*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.963e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.24) ; (omega_q = 4.921e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.09,  0.09,  0.19) ; (omega_q = 4.012e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.527e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.746e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.11,  0.11,  0.21) ; (omega_q = 6.570e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.16) ; (omega_q = 4.970e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.963e-08*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.09,  0.09,  0.19) ; (omega_q = 7.317e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.07,  0.07,  0.13) ; (omega_q = 5.150e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.244e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.861e-08*i)
#
#
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.315e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.16) ; (omega_q = 7.449e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.05,  0.05,  0.11) ; (omega_q = 4.787e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.632e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.652e-08*i)
#
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.244e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.07,  0.07,  0.13) ; (omega_q = 7.078e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04,  0.04,  0.08) ; (omega_q = 3.995e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.861e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.315e-08*i)
#
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 2.864e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.05,  0.05,  0.11) ; (omega_q = 6.269e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.632e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.652e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 1.900e-02*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.348e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 1.495e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04,  0.04,  0.08) ; (omega_q = 5.080e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.908e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.542e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.125e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 3.578e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.631e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.557e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.827e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.348e-08*i)
#
#
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 1.849e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 1.330e-01*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.631e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.110e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.827e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.542e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.327e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.02,  0.00,  0.02) ; (omega_q = 2.532e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.908e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 2.565e-01*i)
#
#
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.125e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 1.697e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.04,  0.00,  0.04) ; (omega_q = 4.954e-01*i)
# WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.06) ; (omega_q = 3.610e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.327e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.06,  0.00,  0.06) ; (omega_q = 7.161e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 3.304e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.08) ; (omega_q = 4.371e-01*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.827e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 5.575e-03*i)WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.06) ; (omega_q = 4.737e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.00,  0.08) ; (omega_q = 9.058e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.10,  0.10,  0.10) ; (omega_q = 4.744e-01*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.08) ; (omega_q = 5.917e-01*i)WARNING, 2 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 1.917e-02*i)WARNING, 1 imaginary frequencies at q = ( 0.10,  0.00,  0.10) ; (omega_q = 1.056e+00*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.575e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.12) ; (omega_q = 4.590e-01*i)
#
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.498e-08*i)
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.827e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.997e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 8.656e-03*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.511e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.198e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.10,  0.10,  0.10) ; (omega_q = 6.774e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.12,  0.00,  0.12) ; (omega_q = 1.159e+00*i)WARNING, 1 imaginary frequencies at q = ( 0.15,  0.15,  0.15) ; (omega_q = 3.622e-01*i)
#
#
#
#
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.349e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.12) ; (omega_q = 7.245e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.13,  0.00,  0.13) ; (omega_q = 1.210e+00*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.270e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.575e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.498e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.198e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 6.997e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.349e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.15,  0.15,  0.15) ; (omega_q = 7.262e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.511e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 2.095e-02*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.15,  0.00,  0.15) ; (omega_q = 1.202e+00*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.17,  0.17,  0.17) ; (omega_q = 6.737e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.270e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.17,  0.00,  0.17) ; (omega_q = 1.132e+00*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.770e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.19,  0.19,  0.19) ; (omega_q = 5.482e-01*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.19,  0.00,  0.19) ; (omega_q = 9.900e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.21,  0.21,  0.21) ; (omega_q = 2.686e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.556e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.717e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.21,  0.00,  0.21) ; (omega_q = 7.521e-01*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.770e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.126e-08*i)
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.23,  0.00,  0.23) ; (omega_q = 2.730e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.15,  0.15,  0.29) ; (omega_q = 2.533e-01*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.556e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.717e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.126e-08*i)
#
#
#
# WARNING, 1 imaginary frequencies at q = ( 0.13,  0.13,  0.27) ; (omega_q = 7.235e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.24) ; (omega_q = 9.333e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.11,  0.11,  0.21) ; (omega_q = 1.043e+00*i)
# WARNING, 1 imaginary frequencies at q = ( 0.09,  0.09,  0.19) ; (omega_q = 1.081e+00*i)
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.16) ; (omega_q = 1.057e+00*i)
# WARNING, 1 imaginary frequencies at q = ( 0.07,  0.07,  0.13) ; (omega_q = 9.796e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.05,  0.05,  0.11) ; (omega_q = 8.529e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.04,  0.04,  0.08) ; (omega_q = 6.830e-01*i)
# WARNING, 2 imaginary frequencies at q = ( 0.03,  0.03,  0.05) ; (omega_q = 4.774e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.625e-08*i)WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.524e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.01,  0.01,  0.03) ; (omega_q = 2.456e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.924e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.393e-08*i)
#
# WARNING, 3 imaginary frequencies at q = ( 0.02,  0.02,  0.02) ; (omega_q = 2.274e-01*i)
# WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.778e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.625e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.277e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.393e-08*i)
# WARNING, 3 imaginary frequencies at q = ( 0.04,  0.04,  0.04) ; (omega_q = 4.441e-01*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 5.924e-08*i)
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.524e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.099e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.517e-08*i)WARNING, 3 imaginary frequencies at q = ( 0.06,  0.06,  0.06) ; (omega_q = 6.402e-01*i)
#
#
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 8.277e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.08,  0.08,  0.08) ; (omega_q = 8.064e-01*i)WARNING, 3 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.778e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 7.517e-08*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 4.099e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.10,  0.10,  0.10) ; (omega_q = 9.349e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.262e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.12,  0.12,  0.12) ; (omega_q = 1.019e+00*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.378e-08*i)WARNING, 1 imaginary frequencies at q = ( 0.15,  0.15,  0.15) ; (omega_q = 1.051e+00*i)
#
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 2.262e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.17,  0.17,  0.17) ; (omega_q = 1.025e+00*i)
# WARNING, 1 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 3.378e-08*i)
# WARNING, 1 imaginary frequencies at q = ( 0.19,  0.19,  0.19) ; (omega_q = 9.301e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.21,  0.21,  0.21) ; (omega_q = 7.410e-01*i)
# WARNING, 1 imaginary frequencies at q = ( 0.23,  0.23,  0.23) ; (omega_q = 3.438e-01*i)

# %%
# Get band structure
# Phonon calculator
calc = KIM(potential)
calc.set_parameters(active_member_id=[[0], [0]])
ph = Phonons(
    atoms,
    calc,
    supercell=(7, 7, 7),
    delta=0.1,
    name=RES_DIR / "000" / "phonon_diamond",
)
ph.run()
ph.read(acoustic=True)
path = atoms.cell.bandpath("GXKGL", npoints=100)
bs = ph.get_band_structure(path)
# Out:
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.246e-08*i)
# WARNING, 2 imaginary frequencies at q = ( 0.00,  0.00,  0.00) ; (omega_q = 9.246e-08*i)

# %%
# Convert to THz
conversion = 4.136e-3 # 1 Thz = 4.136 meV
energies /= conversion

labels = list(bs.get_labels())
labels[2] = [r"$\Gamma$", r"$X$", r"$K$", r"$\Gamma$", r"$L$"]
mean_energies = np.mean(energies, axis=0)
error_energies = np.std(energies, axis=0)

# %%
# Export the data needed to plot the result
plot_data_dict = {
    "energies": {"values": energies, "metadata": "Phonon dispersion energies in THz"},
    "labels": labels,
}
with open(RES_DIR / "uncertainty_phonon_dispersion_diamond.pkl", "wb") as f:
    pickle.dump(plot_data_dict, f, protocol=4)

# %%
colors = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown"]
plt.figure()

for ii, eng in enumerate(mean_energies.T):
    plt.fill_between(
        labels[0],
        eng - error_energies[:, ii],
        eng + error_energies[:, ii],
        color=colors[ii],
        alpha=0.3,
    )
    plt.plot(labels[0], eng, c=colors[ii])

for xcoord, name in zip(labels[1], labels[2]):
    plt.axvline(xcoord, c="k", ls="--")
plt.xticks(labels[1], labels[2])
plt.xlim(labels[1][[0, -1]])
plt.ylim(0, 50)
plt.ylabel("Energies (THz)")
plt.show()
