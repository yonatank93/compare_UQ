# %%
from pathlib import Path

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("default")

# %%
# Paths
FILE_DIR = Path().absolute()
ROOT_DIR = FILE_DIR.parent
RES_DIR = ROOT_DIR / "results"

# Architectures
partition = ["mingjian"]
nnodes = [64, 128, 196]
archs = [
    f"{part}_partition_{n1}_{n2}_{n3}"
    for part in partition
    for n1 in nnodes
    for n2 in nnodes
    for n3 in nnodes
]

# Total number of parameters
ninput = 51
noutput = 1

nparams = []
for n1 in nnodes:
    for n2 in nnodes:
        for n3 in nnodes:
            nparams = np.append(nparams, (ninput*n1)+n1 + (n1*n2)+n2 + (n2*n3)+n3 + (n3*noutput)+noutput)

# DFT data
dft_data = np.loadtxt(ROOT_DIR.parent / "energyvslatconst/dft_data.txt", delimiter=",")

# Lattice parameters
ainit = 2.466
alist = np.linspace(0.93, 1.09, 21) * ainit

# %%
nparams
# Out:
# array([11713., 15937., 20425., 19969., 28289., 37129., 28741., 41413.,
#        54877., 19137., 23361., 27849., 31489., 39809., 48649., 44613.,
#        57285., 70749., 27025., 31249., 35737., 43729., 52049., 60889.,
#        61477., 74149., 87613.])

# %%
archs
# Out:
# ['mingjian_partition_64_64_64',
#  'mingjian_partition_64_64_128',
#  'mingjian_partition_64_64_196',
#  'mingjian_partition_64_128_64',
#  'mingjian_partition_64_128_128',
#  'mingjian_partition_64_128_196',
#  'mingjian_partition_64_196_64',
#  'mingjian_partition_64_196_128',
#  'mingjian_partition_64_196_196',
#  'mingjian_partition_128_64_64',
#  'mingjian_partition_128_64_128',
#  'mingjian_partition_128_64_196',
#  'mingjian_partition_128_128_64',
#  'mingjian_partition_128_128_128',
#  'mingjian_partition_128_128_196',
#  'mingjian_partition_128_196_64',
#  'mingjian_partition_128_196_128',
#  'mingjian_partition_128_196_196',
#  'mingjian_partition_196_64_64',
#  'mingjian_partition_196_64_128',
#  'mingjian_partition_196_64_196',
#  'mingjian_partition_196_128_64',
#  'mingjian_partition_196_128_128',
#  'mingjian_partition_196_128_196',
#  'mingjian_partition_196_196_64',
#  'mingjian_partition_196_196_128',
#  'mingjian_partition_196_196_196']

# %%
idx_sort = np.argsort(nparams)
cmap = mpl.colormaps["inferno"]
colors = cmap(np.linspace(0, 1, len(nparams)))

# %%
_, ax1 = plt.subplots()  # For energy mean
_, ax2 = plt.subplots()  # For energy uncertainty
for ii, idx in enumerate(idx_sort):
    arch = archs[idx]
    CASE_DIR = RES_DIR / arch
    preds_data = np.load(CASE_DIR / "uncertainty_energy_vs_latconst_graphene.npz")
    energy_ensembles = preds_data["energy_ensembles"]
    energy_mean = np.mean(energy_ensembles, axis=0)
    energy_uncert = np.std(energy_ensembles, axis=0)

    ax1.plot(alist, energy_mean, label=arch[19:], c=colors[ii])
    ax2.plot(alist, energy_uncert, label=arch[19:], c=colors[ii])

ax1.plot(*(dft_data.T), "ko")
ax1.set_xlabel(r"Lattice constant $a$ $(\mathrm{\AA})$")
ax1.set_ylabel("Energy mean (eV/atom)")
ax1.legend(bbox_to_anchor=(1, 1))

ax2.set_yscale("log")
ax2.set_xlabel(r"Lattice constant $a$ $(\mathrm{\AA})$")
ax2.set_ylabel("Energy uncertainty (eV/atom)")
plt.show()
