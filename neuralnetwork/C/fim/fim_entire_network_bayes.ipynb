# %% [markdown]
# Compute the FIM of the entire neural network model using autograd functionality in pytorch.

# %%
from pathlib import Path
import json
import pickle
from tqdm import tqdm
import subprocess
from multiprocessing import Pool


import numpy as np
import scipy
from scipy.optimize import least_squares
import matplotlib as mpl
import matplotlib.pyplot as plt
import torch

from kliff import nn
from kliff.calculators import CalculatorTorch
from kliff.dataset import Dataset
from kliff.dataset.weight import Weight
from kliff.descriptors import SymmetryFunction
from kliff.loss import Loss
from kliff.models import NeuralNetwork

# Random seed
seed = 1
np.random.seed(seed)
torch.manual_seed(seed)

# %matplotlib inline
plt.style.use("default")

# %% [markdown]
# # Setup

# %% [markdown]
# ## Variables

# %%
# Read setting file
WORK_DIR = Path().absolute()
ROOT_DIR = WORK_DIR.parent
DATA_DIR = ROOT_DIR / "data"
with open(ROOT_DIR / "settings.json", "r") as f:
    settings = json.load(f)
partition = settings["partition"]
suffix = "_".join([str(n) for n in settings["Nnodes"]])
PART_DIR = DATA_DIR / f"{partition}_partition_data"
FP_DIR = PART_DIR / "fingerprints"
RES_DIR = WORK_DIR / "results" / f"{partition}_partition_{suffix}"
if not RES_DIR.exists():
    RES_DIR.mkdir(parents=True)
JAC_DIR = RES_DIR / "Jacobian"
if not JAC_DIR.exists():
    JAC_DIR.mkdir(parents=True)
test_val = "validation"

# %% [markdown]
# ## Model

# %%
# Architecture
Nlayers = settings["Nlayers"]  # Number of layers, excluding input layer, including outpt layer
Nnodes = settings["Nnodes"]  # Number of nodes per hidden layer
dropout_ratio = 0.0  # Don't use dropout

# %%
# Descriptor
descriptor = SymmetryFunction(
    cut_name="cos", cut_dists={"C-C": 5.0}, hyperparams="set51", normalize=True
)
model = NeuralNetwork(descriptor)

# Layers
hidden_layer_mappings = []
for ii in range(Nlayers - 2):
    hidden_layer_mappings.append(nn.Dropout(dropout_ratio))
    hidden_layer_mappings.append(nn.Linear(Nnodes[ii], Nnodes[ii + 1]))
    hidden_layer_mappings.append(nn.Tanh())

model.add_layers(
    # input layer
    nn.Linear(descriptor.get_size(), Nnodes[0]),  # Mapping from input layer to the first
    nn.Tanh(),  # hidden layer
    # hidden layer(s)
    *hidden_layer_mappings,  # Mappings between hidden layers in the middle
    # hidden layer(s)
    nn.Dropout(dropout_ratio),  # Mapping from the last hidden layer to the output layer
    nn.Linear(Nnodes[-1], 1),
    # output layer
)

# Load best model
orig_model_path = (
    ROOT_DIR
    / "training_dropout"
    / "results"
    / "training"
    / f"{partition}_partition_{suffix}"
    / "model_best_train.pkl"
)
model.load(orig_model_path)
# Out:
# 2024-07-01 21:14:46.882 | INFO     | kliff.models.model_torch:load:117 - Model loaded from `/data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/training_dropout/results/training/mingjian_partition_128_128_128/model_best_train.pkl`

# %% [markdown]
# ## Training set and calculator

# %%
# testing set
dataset_path = PART_DIR / "carbon_test_set"
weight = Weight(energy_weight=1.0, forces_weight=np.sqrt(0.1))
tset = Dataset(dataset_path, weight)
configs = tset.get_configs()
nconfigs = len(configs)
print("Total number of configurations:", nconfigs)

# calculator
gpu = False
calc = CalculatorTorch(model, gpu=gpu)
_ = calc.create(
    configs,
    nprocs=20,
    reuse=True,
    fingerprints_filename=FP_DIR / f"fingerprints_test.pkl",
    fingerprints_mean_stdev_filename=FP_DIR / f"fingerprints_test_mean_and_stdev.pkl",
)
bestfit_params = calc.get_opt_params()
# Out:
# 2024-07-01 21:14:47.310 | INFO     | kliff.dataset.dataset:_read:398 - 444 configurations read from /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/data/mingjian_partition_data/carbon_test_set
# 2024-07-01 21:14:47.315 | INFO     | kliff.calculators.calculator_torch:_get_device:592 - Training on cpu
# 2024-07-01 21:14:47.319 | INFO     | kliff.calculators.calculator_torch:create:93 - Reuse fingerprints `/data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/data/mingjian_partition_data/fingerprints/fingerprints_test.pkl`
# 2024-07-01 21:14:47.322 | INFO     | kliff.calculators.calculator_torch:create:111 - Reuse fingerprints mean and stdev `/data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/data/mingjian_partition_data/fingerprints/fingerprints_test_mean_and_stdev.pkl`
# Total number of configurations: 444

# %%
# Loss function
residual_data = {"normalize_by_natoms": True}
loss = Loss(calc, residual_data=residual_data)

# %% [markdown]
# # Real calculation

# %%
# Total number of parameters, i.e., weights and biases
nparams = calc.get_num_opt_params()

# Require gradient for all layers
for layer in model.layers:
    layer.requires_grad_(True)

# %%
# Each element in the loader only contains 1 configuration
loader = calc.get_compute_arguments(1)
loader_list = list(loader)  # Convert to list to make it easier to index

# %%
# Test-validation split
# Load index
with open(JAC_DIR / "test_validation_idx_split.pkl", "rb") as f:
    idx_split = pickle.load(f)
idx_test = idx_split["test"]
idx_val = idx_split["validation"]

loader_list_test = [loader_list[ii] for ii in idx_test]
loader_list_val = [loader_list[ii] for ii in idx_val]

# %%
# Compute the minimum cost to be used later in the notebook
C0_times_2_test = loss._get_loss_epoch(loader_list_test)
C0_times_2_val = loss._get_loss_epoch(loader_list_val)

# %% [markdown]
# ## Reference data

# %%
reference_energy = []
energy_natoms = []
for batch in loader:
    batch_energy = np.array([float(sample["energy"]) for sample in batch])
    batch_natoms = np.array([sample["forces"].shape[0] for sample in batch])
    reference_energy = np.append(reference_energy, batch_energy)
    energy_natoms = np.append(energy_natoms, batch_natoms)
print(len(reference_energy))
# Out:
# 444

# %%
reference_forces = []
forces_natoms = []
for batch in loader:
    batch_forces = [sample["forces"].numpy().flatten() for sample in batch]
    batch_natoms = [
        np.repeat(sample["forces"].shape[0], np.prod(sample["forces"].shape))
        for sample in batch
    ]
    reference_forces = np.append(reference_forces, np.concatenate(batch_forces))
    forces_natoms = np.append(forces_natoms, np.concatenate(batch_natoms))
print(reference_forces.shape)
# Out:
# (68046,)

# %%
# Total number of predictions
npreds = len(reference_energy) + len(reference_forces)

# %% [markdown]
# ## Eigenvalue analysis

# %% [markdown]
# **NOTE:**
# The eigenvalues are sorted from the smallest to the largest.

# %%
# Load the eigenvalues result
eigvals_file = JAC_DIR / f"eighvals_entire_network_{test_val}.npy"
if eigvals_file.exists():
    print("Loading...")
    eigvals = np.load(eigvals_file)
else:
    msg = (
        "Please run the companion script (fim_entire_network.py) "
        "to generate the result"
    )
    raise FileNotFoundError(msg)
# Out:
# Loading...

# %%
# # Plot eigenvalues
# plt.figure()
# plt.title("Eigenvalues of the FIM")
# plt.plot(eigvals[::-1])  # Plot the largest to the smallest eigenvalue
# plt.yscale("log")
# plt.ylim(bottom=1e-12)

# # Inset axis
# ax = plt.gca()
# x1, x2, y1, y2 = -50, 1000, 1e-3, 1e6  # subregion of the original image
# axins = ax.inset_axes(
#     [0.5, 0.5, 0.47, 0.47], xlim=(x1, x2), ylim=(y1, y2), yscale="log"
# )
# axins.plot(eigvals[::-1])
# axins.axvline(128, color="k", ls="--")  # There are 129 parameters of the last layer
# ax.indicate_inset_zoom(axins, edgecolor="black")

# plt.show()

# %%
# # Count the eigenvalues
# eigvals_lower_bounds_list = np.logspace(-16, 4, 101)
# num_larger_eigvals = [np.sum(eigvals > lb) for lb in eigvals_lower_bounds_list]

# plt.figure()
# plt.title("Number of eigenvalues larger than some cutoff")
# plt.plot(eigvals_lower_bounds_list, num_larger_eigvals)
# plt.xscale("log")
# plt.ylim(bottom=0)
# plt.xlabel("Eigenvalue cutoff")

# # Inset axis
# ax = plt.gca()
# x1, x2, y1, y2 = 1e-3, 1e4, 0, 1000  # subregion of the original image
# axins = ax.inset_axes(
#     [0.5, 0.5, 0.47, 0.47], xlim=(x1, x2), ylim=(y1, y2), xscale="log"
# )
# axins.plot(eigvals_lower_bounds_list, num_larger_eigvals)
# axins.axhline(129, color="k", ls="--")  # There are 129 parameters of the last layer
# ax.indicate_inset_zoom(axins, edgecolor="black")

# plt.show()

# %% [markdown]
# Main problem: What is the number of effective parameters?
#
# Some approach:
# * In our previous work, we showed that the number of eigenvalues larger than $T_0 = 2 C_0 / N$ (denoted as $n$) is related to the number of effective parameters.
# * So, we will find $N$ such that it equals to $n$.
# We will turn this into an optimization problem.

# %%
# Function to optimize, which computes the difference between N and d
def compute_T(N):
    if test_val == "test":
        return C0_times_2_test / N
    else:
        return C0_times_2_val / N


def find_n_given_N(N):
    T = compute_T(N)
    return sum(eigvals > T)


def find_optimal_N_objective(N):
    n = find_n_given_N(N)
    return N - n


print("Optimization to find the number of effective parameters")
opt = least_squares(find_optimal_N_objective, nparams / 2)
opt_N = int(np.ceil(opt.x))  # Number of effective parameters, round it up
opt_eigvals = eigvals[-opt_N:]  # Eigenvalues of the effective parameters
print("Temperature:", compute_T(opt_N))
opt
# Out:
# Optimization to find the number of effective parameters
# Temperature: 6.943341965140988e-05
#  active_mask: array([0.])
#         cost: 0.0
#          fun: array([0.])
#         grad: array([0.])
#          jac: array([[1.]])
#      message: '`gtol` termination condition is satisfied.'
#         nfev: 7
#         njev: 7
#   optimality: 0.0
#       status: 1
#      success: True
#            x: array([578.])

# %%
# Plot eigenvalues
plt.figure()
plt.title("Eigenvalues of the FIM")
plt.plot(eigvals[::-1])  # Plot the largest to the smallest eigenvalue
plt.axvline(opt_N, c="k", ls="--")
plt.yscale("log")
plt.ylim(bottom=1e-12)

# Inset axis
ax = plt.gca()
x1, x2, y1, y2 = -50, 2000, 1e-4, 1e6  # subregion of the original image
axins = ax.inset_axes(
    [0.5, 0.5, 0.47, 0.47], xlim=(x1, x2), ylim=(y1, y2), yscale="log"
)
axins.plot(eigvals[::-1])
axins.axvline(opt_N, c="k", ls="--")
ax.indicate_inset_zoom(axins, edgecolor="black")

plt.show()

# %% [markdown]
# It is interesting that the number of effective parameters we found this way is located near the elbow.
# I don't think this is a coincidence.
# I have qualitative argument why this behavior is not a coincidence, and it can be shown using the following plot.

# %%
# Look at N vs n
N = np.arange(nparams / 10) + 1
with Pool(25) as p:
    n = np.array(list(p.imap(find_n_given_N, tqdm(N))))
# Out:
# 100%|█████████████████████████████████████████████████████████████| 3981/3981 [00:32<00:00, 120.71it/s]

# %%
plt.figure()
plt.plot(N, N, label="N")
plt.plot(N, n, label="n")
plt.legend()
plt.show()

# %% [markdown]
# Some description why we expect the number of effective parameters is around the elbow.

# %% [markdown]
# ## Eigenvectors analysis

# %% [markdown]
# **NOTE:** The eigenvalues are sorted from the smallest to the largest.

# %%
# Load the eigenvalues result
eigvecs_file = JAC_DIR / f"eighvecs_entire_network_{test_val}.npy"
if eigvecs_file.exists():
    print("Loading...")
    eigvecs = np.load(eigvecs_file)
else:
    msg = (
        "Please run the companion script (fim_entire_network.py) "
        "to generate the result"
    )
    raise FileNotFoundError(msg)
# Out:
# Loading...

# %%
# Get the eigenvectors for the effective parameters
opt_eigvecs = eigvecs[:, -opt_N:]
# The following variables are to help plot the eigenvectors
nparams_per_layer = np.append(0, calc.get_size_opt_params()[1])
eigvecs_plot_titles = [
    "Weights layer 1",
    "Bias layer 1",
    "Weights layer 2",
    "Bias layer 2",
    "Weights layer 3",
    "Bias layer 3",
    "Weights layer 4",
    "Bias layer 4",
]
nparams_per_layer
# Out:
# array([    0,  6528,   128, 16384,   128, 16384,   128,   128,     1])

# %% [markdown]
# Note that on the following plots, the left-most column is the sloppiest, and the right-most column is the stiffest

# %%
# Plot participation factor for the relevant parameters. Divide the rows different
# NN layers. This is to help see which layers are more important.
for ii in range(len(nparams_per_layer) - 1):
    start = sum(nparams_per_layer[: ii + 1])
    end = start + nparams_per_layer[ii + 1]
    # print(ii, start, end)
    plt.figure()
    plt.title(eigvecs_plot_titles[ii])
    plt.imshow(
        opt_eigvecs[start:end] ** 2 + 1e-16,
        aspect="auto",
        cmap="inferno",
        norm=mpl.colors.LogNorm(vmin=1e-4, vmax=0.1),
    )

    plt.colorbar(label="Participation factor")
    plt.xlabel(r"Sloppy $\rightarrow$ Stiff")
plt.show()

# %% [markdown]
# # Model ensemble

# %% [markdown]
# Now that we know the number of effective parameters, we can compute the overall temperature scaling factor for the likelihood.
# Then, the next step is to get the posterior, which we assume to be a Gaussian centered at the optimal parameters.
# The covariance of the Gaussian is the inverse of the FIM likelihood plus FIM prior.
# Finally, the prior to compute the FIM will be chosen to be a Xavier normal distribution, where the variance for each layer is given by
# \begin{equation}
#     \sigma^2 = \frac{2}{\text{fan}_{in} + \text{fan}_{out}},
# \end{equation}
# where $\text{fan}_{in}$ is the number of input features and $\text{fan}_{out}$ is the number of output features.
#
# In the following, we will compute the covariance matrix of the parameters.
# However, note that we will just vary the effective parameters and fix the rest.
# We can do this since we know the number of effective parameters and the eigenvectors of the FIM likelihood.

# %%
# Construct the FIM of the prior
def compute_xavier_variance(fan_in, fan_out):
    """Compute the Xavier normal variance given number of input and output features."""
    return 2 / (fan_in + fan_out)


# Construct variance for the prior
var_prior = []
for layer in model.layers:
    if isinstance(layer, torch.nn.Linear):
        fan_in = layer.in_features
        fan_out = layer.out_features
        s2 = compute_xavier_variance(fan_in, fan_out)
        var_weight = np.ones(fan_in * fan_out) * s2
        var_bias = np.ones(fan_out)
        var_layer = np.append(var_weight, var_bias)
        var_prior = np.append(var_prior, var_layer)
# Construct the FIM of the prior
fim_prior = scipy.sparse.diags(np.ones_like(var_prior) / var_prior)

# %% [markdown]
# To sample only the effective parameters, we will transform the space and do the sampling in the eigenspace instead.
# Then later we will transform back the samples to the original parameter space.
#
# In the eigenspace, the covariance matrix is given by
# \begin{equation}
#     \tilde{\text{Cov}} = \left( \Lambda_L + V_L^T \mathcal{I}_\pi V_L \right)^{-1},
# \end{equation}
# where $\Lambda_L$ is a matrix of eigenvalues of the FIM likelihood $\mathcal{I}_L$ with the corresponding eigenvectors $V_L$ and $\mathcal{I}_\pi$ is the FIM from the prior, which is in this case a diagonal matrix.
#
# After we get the covariance matrix in eigenspace, we will do multivariate normal sampling in the eigenspace.
# Then, we will transform the samples to the original parameter space.

# %%
# Parameter samples
p0 = bestfit_params
if test_val == "test":
    C0_times_2 = C0_times_2_test
else:
    C0_times_2 = C0_times_2_val

param_samples_file = RES_DIR / "samples_bayes_parameters.npy"
if param_samples_file.exists():
    print("Loading...")
    param_samples = np.load(param_samples_file)
else:
    # Compute the second term in the sum
    VtIV = eigvecs.T @ fim_prior @ eigvecs  # Essentially rotate I_pi in eigenbasis
    
    # Covariance inverse
    # Temperature
    T = C0_times_2 / opt_N
    # Also divide the eigenvalues of the FIM likelihood with the temperature
    cov_eig_inv = scipy.sparse.diags(eigvals) / T + VtIV
    
    # But, we don't want to take all these values. We will fix the irrelevant parameters.
    # So, we will only take the last Neff columns and rows (since the eigenvalues are
    # sorted in the increasing order).
    cov_eig_inv_eff = cov_eig_inv[-opt_N:, -opt_N:]
    
    # Inverse this matrix to get the covariance in eigenspace
    l, v = np.linalg.eigh(cov_eig_inv_eff)
    cov_eig = v @ np.diag(1 / l) @ v.T
    
    # After we get the covariance matrix in eigenspace, we will do multivariate normal
    # sampling in the eigenspace. Then, we will transform the samples to the original
    # parameter space.
    # Sampling in the eigenspace
    nsamples = 100
    samples_eig_eff = np.random.multivariate_normal(
        mean=np.zeros_like(l), cov=cov_eig, size=nsamples
    )
    
    # Transform these samples to the original parameter space.
    # However, note that the samples will still have zero mean.
    # The ordering here considers the shape of the array.
    samples_zero_mean = samples_eig_eff @ eigvecs[:, -opt_N:].T
    
    # Shift the samples by the mean, which is the optimal parameters
    param_samples = samples_zero_mean + p0

    # Export the samples
    param_samples_file = RES_DIR / "samples_bayes_parameters.npy"
    np.save(param_samples_file, param_samples)

# %%
# # Some plots of the samples
# plt.figure()
# plt.plot(np.std(param_samples, axis=0))
# plt.yscale("log")
# plt.xlabel("Parameter index")
# plt.ylabel("Standard deviation")
# plt.show()

# %%
# Write and install model ensembles
for ii, params in tqdm(enumerate(param_samples), total=len(param_samples)):
    # Write the model
    complete_params = bestfit_params.copy()
    complete_params[-nparams:] = params
    calc.update_model_params(complete_params)  # Update parameters
    # Install model
    modelpath = RES_DIR / f"{ii:03d}" / f"DUNN_C_fimbayes_{ii:03d}"
    model.write_kim_model(modelpath)  # Write
# Out:
#   0%|                                                                          | 0/100 [00:00<?, ?it/s]2024-07-01 21:29:07.662 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/000/DUNN_C_fimbayes_000.
#   1%|▋                                                                 | 1/100 [00:00<00:33,  2.98it/s]2024-07-01 21:29:07.999 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/001/DUNN_C_fimbayes_001.
#   2%|█▎                                                                | 2/100 [00:00<00:32,  2.98it/s]2024-07-01 21:29:08.332 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/002/DUNN_C_fimbayes_002.
#   3%|█▉                                                                | 3/100 [00:01<00:32,  2.99it/s]2024-07-01 21:29:08.663 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/003/DUNN_C_fimbayes_003.
#   4%|██▋                                                               | 4/100 [00:01<00:31,  3.00it/s]2024-07-01 21:29:09.000 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/004/DUNN_C_fimbayes_004.
#   5%|███▎                                                              | 5/100 [00:01<00:31,  2.99it/s]2024-07-01 21:29:09.533 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/005/DUNN_C_fimbayes_005.
#   6%|███▉                                                              | 6/100 [00:02<00:37,  2.54it/s]2024-07-01 21:29:10.341 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/006/DUNN_C_fimbayes_006.
#   7%|████▌                                                             | 7/100 [00:03<00:48,  1.93it/s]2024-07-01 21:29:11.148 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/007/DUNN_C_fimbayes_007.
#   8%|█████▎                                                            | 8/100 [00:03<00:55,  1.65it/s]2024-07-01 21:29:11.957 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/008/DUNN_C_fimbayes_008.
#   9%|█████▉                                                            | 9/100 [00:04<01:00,  1.50it/s]2024-07-01 21:29:12.766 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/009/DUNN_C_fimbayes_009.
#  10%|██████▌                                                          | 10/100 [00:05<01:03,  1.41it/s]2024-07-01 21:29:13.576 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/010/DUNN_C_fimbayes_010.
#  11%|███████▏                                                         | 11/100 [00:06<01:05,  1.35it/s]2024-07-01 21:29:14.384 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/011/DUNN_C_fimbayes_011.
#  12%|███████▊                                                         | 12/100 [00:07<01:06,  1.32it/s]2024-07-01 21:29:15.219 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/012/DUNN_C_fimbayes_012.
#  13%|████████▍                                                        | 13/100 [00:07<01:08,  1.28it/s]2024-07-01 21:29:16.032 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128
| INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/092/DUNN_C_fimbayes_092.
#  93%|████████████████████████████████████████████████████████████▍    | 93/100 [01:12<00:05,  1.23it/s]2024-07-01 21:30:20.798 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/093/DUNN_C_fimbayes_093.
#  94%|█████████████████████████████████████████████████████████████    | 94/100 [01:13<00:04,  1.23it/s]2024-07-01 21:30:21.603 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/094/DUNN_C_fimbayes_094.
#  95%|█████████████████████████████████████████████████████████████▊   | 95/100 [01:14<00:04,  1.24it/s]2024-07-01 21:30:22.413 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/095/DUNN_C_fimbayes_095.
#  96%|██████████████████████████████████████████████████████████████▍  | 96/100 [01:15<00:03,  1.24it/s]2024-07-01 21:30:23.226 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/096/DUNN_C_fimbayes_096.
#  97%|███████████████████████████████████████████████████████████████  | 97/100 [01:15<00:02,  1.23it/s]2024-07-01 21:30:24.037 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/097/DUNN_C_fimbayes_097.
#  98%|███████████████████████████████████████████████████████████████▋ | 98/100 [01:16<00:01,  1.23it/s]2024-07-01 21:30:24.856 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/098/DUNN_C_fimbayes_098.
#  99%|████████████████████████████████████████████████████████████████▎| 99/100 [01:17<00:00,  1.23it/s]2024-07-01 21:30:25.677 | INFO     | kliff.models.neural_network:write_kim_model:121 - KLIFF trained model written to /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/099/DUNN_C_fimbayes_099.
# 100%|████████████████████████████████████████████████████████████████| 100/100 [01:18<00:00,  1.28it/s]

# %%
def install_uninstall_model(modelname, mode="install"):
    """This function will install or remove KIM model."""
    kim_command = "kim-api-collections-management"
    if mode == "install":
        flags = ["install", "user"]
    elif mode == "uninstall":
        flags = ["remove", "--force"]
        modelname = Path(modelname).name
    command = np.concatenate(([kim_command], flags, [modelname]))
    subprocess.run(command)


def install_uninstall_wrapper(ii):
    modelname = RES_DIR / f"{ii:03d}" / f"DUNN_C_fimbayes_{ii:03d}"
    # Uninstall first to make sure we don't use the wrong models later
    install_uninstall_model(modelname, "uninstall")
    # Install this model ensemble
    install_uninstall_model(modelname, "install")


with Pool(25) as p:
    p.map(install_uninstall_wrapper, range(100))
# Out:
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_004'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_008'. [done]
#
# Success!
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_006'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_002'. This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [done]
#
# Success!
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_011'. This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_022'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_013'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_012'. [done]
#
# Success!
# [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_003'. This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_018'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_000'. [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_019'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_014'. [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_020'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_009'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_016'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_021'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_024'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_007'. This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_023'. [done]
#
# Success!
# [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_015'. [done]
#
# Success!
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_017'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_001'. [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_005'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_010'. [done]
#
# Success!
# [done]
#
# Success!
# Found local item named: DUNN_C_fimbayes_011.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/011/DUNN_C_fimbayes_011.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_006.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/006/DUNN_C_fimbayes_006.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_013.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/013/DUNN_C_fimbayes_013.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_004.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/004/DUNN_C_fimbayes_004.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_002.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/002/DUNN_C_fimbayes_002.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
# Found local item named: DUNN_C_fimbayes_016.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/016/DUNN_C_fimbayes_016.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_000.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/000/DUNN_C_fimbayes_000.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_017.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/017/DUNN_C_fimbayes_017.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_012.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/012/DUNN_C_fimbayes_012.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_015.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/015/DUNN_C_fimbayes_015.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_008.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/008/DUNN_C_fimbayes_008.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_018.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/018/DUNN_C_fimbayes_018.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_023.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/023/DUNN_C_fimbayes_023.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_003.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/003/DUNN_C_fimbayes_003.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_014.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/014/DUNN_C_fimbayes_014.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_020.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/020/DUNN_C_fimbayes_020.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_007.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/007/DUNN_C_fimbayes_007.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_010.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/010/DUNN_C_fimbayes_010.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_005.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/005/DUNN_C_fimbayes_005.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_021.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/021/DUNN_C_fimbayes_021.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_022.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/022/DUNN_C_fimbayes_022.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_009.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/009/DUNN_C_fimbayes_009.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_019.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/019/DUNN_C_fimbayes_019.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_001.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/001/DUNN_C_fimbayes_001.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_024.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/024/DUNN_C_fimbayes_024.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# [100%] Built target DUNN_C_fimbayes_002
# [100%] Built target DUNN_C_fimbayes_011
# Install the project...
# [100%] Built target DUNN_C_fimbayes_006
# [100%] Built target DUNN_C_fimbayes_016
# [100%] Built target DUNN_C_fimbayes_015
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_002/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_011/libkim-api-portable-model.so
#
# Success!
# Install the project...
# Install the project...
# Install the project...
# [100%] Built target DUNN_C_fimbayes_013
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_006/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_016/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_015/libkim-api-portable-model.so
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_017
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_013/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_014
#
# Success!
# Install the project...
# Install the project...
# [100%] Built target DUNN_C_fimbayes_000
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_017/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_014/libkim-api-portable-model.so
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_004
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_000/libkim-api-portable-model.so
#
# Success!
# Install the project...
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_004/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_025'. [100%] Built target DUNN_C_fimbayes_020
# [100%] Built target DUNN_C_fimbayes_007
# [100%] Built target DUNN_C_fimbayes_018
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_026'. [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_008
# Install the project...
# Install the project...
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_020/libkim-api-portable-model.so
# Install the project...
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_007/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_023
# Install the project...
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_027'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_028'.
# Success!
# [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_029'.
# Success!
# -- Install configuration: "None"
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_018/libkim-api-portable-model.so
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_008/libkim-api-portable-model.so
# [done]
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_012
# Install the project...
#
# Success!
# [100%] Built target DUNN_C_fimbayes_009
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_023/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
#
# Success!
# Install the project...
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_030'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_031'. -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_012/libkim-api-portable-model.so
# Install the project...
# [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_003
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_032'.
# Success!
# [done]
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_009/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [100%] Built target DUNN_C_fimbayes_010
# [100%] Built target DUNN_C_fimbayes_001
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_033'. [100%] Built target DUNN_C_fimbayes_021
# [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_022
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_003/libkim-api-portable-model.so
# Install the project...
# Install the project...
#
# Success!
# -- Install configuration: "None"
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_010/libkim-api-portable-model.so
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_021/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_001/libkim-api-portable-model.so
# Install the project...
#
# Success!
#
# Success!
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_034'. -- Install configuration: "None"
# [100%] Built target DUNN_C_fimbayes_024
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_022/libkim-api-portable-model.so
# [done]
#
# Success!
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_024/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_035'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_036'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_037'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_039'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_038'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_041'. [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_040'. This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_042'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_043'. [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_044'. Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_045'. [done]
#
# Success!
# [done]
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_046'. [done]
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_047'. [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_005
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_005/libkim-api-portable-model.so
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_048'. [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_019
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_019/libkim-api-portable-model.so
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_049'. [done]
#
# Success!
# Found local item named: DUNN_C_fimbayes_025.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/025/DUNN_C_fimbayes_025.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_028.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/028/DUNN_C_fimbayes_028.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_026.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/026/DUNN_C_fimbayes_026.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_030.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/030/DUNN_C_fimbayes_030.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_033.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/033/DUNN_C_fimbayes_033.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_034.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/034/DUNN_C_fimbayes_034.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_029.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/029/DUNN_C_fimbayes_029.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_031.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/031/DUNN_C_fimbayes_031.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_032.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/032/DUNN_C_fimbayes_032.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_035.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/035/DUNN_C_fimbayes_035.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_027.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/027/DUNN_C_fimbayes_027.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_036.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/036/DUNN_C_fimbayes_036.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
# Found local item named: DUNN_C_fimbayes_039.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/039/DUNN_C_fimbayes_039.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_037.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/037/DUNN_C_fimbayes_037.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_041.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/041/DUNN_C_fimbayes_041.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_040.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/040/DUNN_C_fimbayes_040.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_038.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/038/DUNN_C_fimbayes_038.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_044.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/044/DUNN_C_fimbayes_044.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_043.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/043/DUNN_C_fimbayes_043.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_047.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/047/DUNN_C_fimbayes_047.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_042.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/042/DUNN_C_fimbayes_042.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_045.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/045/DUNN_C_fimbayes_045.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_046.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/046/DUNN_C_fimbayes_046.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_048.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/048/DUNN_C_fimbayes_048.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found local item named: DUNN_C_fimbayes_049.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/049/DUNN_C_fimbayes_049.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# [100%] Built target DUNN_C_fimbayes_028
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_028/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_026
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_026/libkim-api-portable-model.so
#
# Success!
# Found installed driver... DUNN__MD_292677547454_000
# [100%] Built target DUNN_C_fimbayes_033
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_033/libkim-api-portable-model.so
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_050'. [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_035
# [100%] Built target DUNN_C_fimbayes_031
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Install the project...
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_051'. Install the project...
# [done]
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_035/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_031/libkim-api-portable-model.so
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_030
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_030/libkim-api-portable-model.so
#
# Success!
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [100%] Built target DUNN_C_fimbayes_032
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_052'. [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_037
# [100%] Built target DUNN_C_fimbayes_034
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_037/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_029
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_032/libkim-api-portable-model.so
#
# Success!
# Install the project...
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_034/libkim-api-portable-model.so
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Install the project...
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_053'. [done]
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_029/libkim-api-portable-model.so
#
# Success!
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_054'. [done]
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_040
# [100%] Built target DUNN_C_fimbayes_041
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_055'. Install the project...
# [100%] Built target DUNN_C_fimbayes_047
# [done]
#
# Success!
# [100%] Built target DUNN_C_fimbayes_043
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_040/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_041/libkim-api-portable-model.so
#
# Success!
#
# Success!
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_043/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_047/libkim-api-portable-model.so
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_038
# This will remove all files associated with these items.
#   Use the '--interactive' option to request confirmation
#   before attempting to remove each item.
# [100%] Built target DUNN_C_fimbayes_025
# Removing '/home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_056'. Install the project...
# [done]
#
# Success!
# -- Install configuration: "None"
# ...
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_078.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/078/DUNN_C_fimbayes_078.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_080.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/080/DUNN_C_fimbayes_080.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_079.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/079/DUNN_C_fimbayes_079.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_082.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/082/DUNN_C_fimbayes_082.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_085.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/085/DUNN_C_fimbayes_085.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_083.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/083/DUNN_C_fimbayes_083.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_081.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/081/DUNN_C_fimbayes_081.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_084.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/084/DUNN_C_fimbayes_084.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_087.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/087/DUNN_C_fimbayes_087.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_086.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/086/DUNN_C_fimbayes_086.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_089.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/089/DUNN_C_fimbayes_089.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_088.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/088/DUNN_C_fimbayes_088.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_090.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/090/DUNN_C_fimbayes_090.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_091.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/091/DUNN_C_fimbayes_091.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_092.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/092/DUNN_C_fimbayes_092.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_094.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/094/DUNN_C_fimbayes_094.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_095.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/095/DUNN_C_fimbayes_095.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
# Found local item named: DUNN_C_fimbayes_093.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/093/DUNN_C_fimbayes_093.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_096.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/096/DUNN_C_fimbayes_096.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found installed driver... DUNN__MD_292677547454_000
# Found local item named: DUNN_C_fimbayes_098.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/098/DUNN_C_fimbayes_098.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_097.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/097/DUNN_C_fimbayes_097.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found local item named: DUNN_C_fimbayes_099.
# In source directory: /data/yonatan/myproject/scripts/compare_UQ/neuralnetwork/C/fim/results/mingjian_partition_128_128_128/099/DUNN_C_fimbayes_099.
#    (If you are trying to install an item from openkim.org
#     rerun this command from a different working directory,
#     or rename the source directory mentioned above.)
#
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# [100%] Built target DUNN_C_fimbayes_075
# Install the project...
# Found installed driver... DUNN__MD_292677547454_000
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_075/libkim-api-portable-model.so
#
# Success!
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# Found installed driver... DUNN__MD_292677547454_000
# [100%] Built target DUNN_C_fimbayes_078
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_078/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_080
# [100%] Built target DUNN_C_fimbayes_079
# [100%] Built target DUNN_C_fimbayes_077
# [100%] Built target DUNN_C_fimbayes_082
# Install the project...
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_080/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_077/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_079/libkim-api-portable-model.so
# Install the project...
#
# Success!
#
# Success!
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_082/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_081
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_081/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_087
# [100%] Built target DUNN_C_fimbayes_085
# Install the project...
# Install the project...
# [100%] Built target DUNN_C_fimbayes_083
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_085/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_087/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_084
#
# Success!
# Install the project...
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_083/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_089
# Install the project...
#
# Success!
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_084/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_088
#
# Success!
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_089/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_088/libkim-api-portable-model.so
#
# Success!
#
# Success!
# [100%] Built target DUNN_C_fimbayes_086
# Install the project...
# [100%] Built target DUNN_C_fimbayes_076
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_086/libkim-api-portable-model.so
#
# Success!
# Install the project...
# [100%] Built target DUNN_C_fimbayes_091
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_076/libkim-api-portable-model.so
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_091/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_094
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_094/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_092
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_092/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_090
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_090/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_093
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_093/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_095
# Install the project...
# [100%] Built target DUNN_C_fimbayes_096
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_095/libkim-api-portable-model.so
# [100%] Built target DUNN_C_fimbayes_098
#
# Success!
# [100%] Built target DUNN_C_fimbayes_099
# Install the project...
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_096/libkim-api-portable-model.so
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_098/libkim-api-portable-model.so
#
# Success!
#
# Success!
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_099/libkim-api-portable-model.so
#
# Success!
# [100%] Built target DUNN_C_fimbayes_097
# Install the project...
# -- Install configuration: "None"
# -- Installing: /home/byu.local/yonatank/.kim-api/2.2.1+GNU.GNU.GNU.2020-12-28-19-51-27/portable-models-dir/DUNN_C_fimbayes_097/libkim-api-portable-model.so
#
# Success!
